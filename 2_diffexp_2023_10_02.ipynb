# %% [markdown]
# # Differential Expression for clinical variables related to T2D

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## 1. Load data

# %%
combined_table = pd.read_csv('results_2023_10_18/combined_data_table.csv', dtype={'public_client_id': str})
# Out:
# /tmp/ipykernel_1103969/3589811407.py:1: DtypeWarning: Columns (992) have mixed types. Specify dtype option on import or set low_memory=False.
#   combined_table = pd.read_csv('results_2023_10_18/combined_data_table.csv', dtype={'public_client_id': str})

# %%
combined_table.index = pd.MultiIndex.from_frame(combined_table[['public_client_id', 'days_in_program']])

# %%
selected_columns_full = np.loadtxt('results_2023_10_18/selected_columns_full.txt', dtype=str, delimiter='\t')
chem_subset_cols = np.loadtxt('results_2023_10_18/chem_subset_cols.txt', dtype=str, delimiter='\t')
selected_chem_bp_cols = np.loadtxt('results_2023_10_18/selected_chem_bp_cols.txt', dtype=str, delimiter='\t')
selected_prot_cols = np.loadtxt('results_2023_10_18/selected_prot_cols.txt', dtype=str, delimiter='\t')
selected_met_cols = np.loadtxt('results_2023_10_18/selected_met_cols.txt', dtype=str, delimiter='\t')

# %%
#  try taking only the first patient?
first_items = []
prev_client = None
for c in combined_table.public_client_id:
    if c == prev_client:
        first_items.append(False)
    else:
        prev_client = c
        first_items.append(True)
first_items = np.array(first_items)

combined_table_unique_subjects = combined_table[first_items]

# %% [markdown]
# ## 2. Do differential expression for proteins and metabolites and clinical data based on delta-HbA1C

# %%
import scipy
import numpy as np

def data_test(data1, data2, test='u', use_fdr=True):
    """
    data1 and data2 are dataframes with the same columns
    Assume that they have the same columns
    NaNs are ignored?
    Do we assume that the data is already log-transformed?
    """
    data1_means = data1.mean(0)
    data2_means = data2.mean(0)
    mean_diff = data1_means - data2_means
    if test == 'u':
        t_test_results = scipy.stats.mannwhitneyu(data1, data2, axis=0, alternative='two-sided')
    elif test == 'w':
        t_test_results = scipy.stats.ranksums(data1, data2, axis=0, alternative='two-sided')
    elif test == 't':
        t_test_results = scipy.stats.ttest_ind(data1, data2, axis=0, alternative='two-sided')
    pvals = t_test_results.pvalue
    if use_fdr:
        pvals = scipy.stats.false_discovery_control(pvals, method='by')
    return mean_diff, pvals

# %%
import random

def get_control_set(normal_table, test_table):
    """
    Gets similar patients based on demographic characteristics
    """
    control_rows = []
    included_indices = set()
    all_similar_indices = set()
    for i, row in test_table.iterrows():
        age = row.age
        is_m = row.is_m
        min_age = age - 2
        max_age = age + 2
        similar_rows = normal_table[(normal_table.is_m == is_m) & (normal_table.age >= min_age) & (normal_table.age <= max_age)]
        indices = similar_rows.index.to_list()
        indices = [x for x in indices if x not in included_indices]
        try:
            sample = random.sample(indices, 2)
            included_indices.update(sample)
        except(ValueError):
            print('unable to find matching sample', age, is_m)
            min_age = age - 10
            max_age = age + 10
            similar_rows = normal_table[(normal_table.is_m == is_m) & (normal_table.age >= min_age) & (normal_table.age <= max_age)]
            indices = similar_rows.index.to_list()
            indices = [x for x in indices if x not in included_indices]
            if len(indices) == 1:
                sample = indices
            elif len(indices) >= 2:
                sample = random.sample(indices, 2)
            else:
                print('no matching sample found')
                sample = []
            included_indices.update(sample)
    return included_indices

# %% [markdown]
# ### Iterating through different clinical variables and thresholds to do tests

# %%
def get_diffexp(data, variable, high_threshold, low_threshold,
                selected_prots=selected_prot_cols, selected_mets=selected_met_cols,
                selected_clinical=selected_chem_bp_cols):
    "Compute differential expression"
    data_high = data[data[variable] >= high_threshold]
    print('number of data points for {0}:'.format(variable), len(data_high))
    data_low = data[data[variable] < low_threshold]
    control_indices = get_control_set(data_low, data_high)
    data_control = data_low.loc[list(control_indices)]
    mean_diff, pvals = data_test(data_high[selected_prots], data_control[selected_prots], test='u')
    pvals = pd.Series(pvals, index=mean_diff.index)
    print('number of significant proteins for {0}:'.format(variable), (pvals < 0.05).sum())
    mets_mean_diff, mets_pvals = data_test(data_high[selected_mets], data_control[selected_mets], test='u')
    mets_pvals = pd.Series(mets_pvals, index=mets_mean_diff.index)
    print('number of significant metabolites for {0}:'.format(variable), (mets_pvals < 0.05).sum())
    chems_mean_diff, chems_pvals = data_test(data_high[selected_clinical], data_control[selected_clinical], test='u')
    chems_pvals = pd.Series(chems_pvals, index=chems_mean_diff.index)
    print('number of significant clinical tests for {0}:'.format(variable), (chems_pvals < 0.05).sum())
    return mean_diff, pvals, mets_mean_diff, mets_pvals, chems_mean_diff, chems_pvals

# %%
def get_diffexp_class(data, variable,
                selected_prots=selected_prot_cols, selected_mets=selected_met_cols,
                selected_clinical=selected_chem_bp_cols):
    "Compute differential expression based on a binarized class variable"
    data_high = data[data[variable]==1]
    print('number of data points for {0}:'.format(variable), len(data_high))
    data_low = data[data[variable]==0]
    control_indices = get_control_set(data_low, data_high)
    data_control = data_low.loc[list(control_indices)]
    mean_diff, pvals = data_test(data_high[selected_prots], data_control[selected_prots], test='u')
    pvals = pd.Series(pvals, index=mean_diff.index)
    print('number of significant proteins for {0}:'.format(variable), (pvals < 0.05).sum())
    mets_mean_diff, mets_pvals = data_test(data_high[selected_mets], data_control[selected_mets], test='u')
    mets_pvals = pd.Series(mets_pvals, index=mets_mean_diff.index)
    print('number of significant metabolites for {0}:'.format(variable), (mets_pvals < 0.05).sum())
    chems_mean_diff, chems_pvals = data_test(data_high[selected_clinical], data_control[selected_clinical], test='u')
    chems_pvals = pd.Series(chems_pvals, index=chems_mean_diff.index)
    print('number of significant clinical tests for {0}:'.format(variable), (chems_pvals < 0.05).sum())
    return mean_diff, pvals, mets_mean_diff, mets_pvals, chems_mean_diff, chems_pvals

# %%
variables = ['d_HbA1C_class', 'd_GLUCOSE_class', 'd_INSULIN_class', 'd_HOMA-IR_class', 'd_GFR_class']
    
# current values - TODO: in the previous analyses, these used all of the tables, not just the data subset. That's not done here.
base_variables = ['GLYCOHEMOGLOBIN A1C', 'GLUCOSE']
base_high_thresholds = [6.5, 125]
base_low_thresholds = [6.5, 125]

# %%
prots_mean_diff = []
prots_pvals = []
mets_mean_diff = []
mets_pvals = []
chems_mean_diff = []
chems_pvals = []
diffexp_outputs = []
base_diffexp_outputs = []
for var in variables:
    diffexp_output = get_diffexp_class(combined_table_unique_subjects, var)
    diffexp_outputs.append(diffexp_output)
for var, low, high in zip(base_variables, base_low_thresholds, base_high_thresholds):
    diffexp_output = get_diffexp(combined_table_unique_subjects,
                                                    var, high, low)
    base_diffexp_outputs.append(diffexp_output)
# Out:
# number of data points for d_HbA1C_class: 185
# unable to find matching sample 18.0 0.0
# number of significant proteins for d_HbA1C_class: 19
# number of significant metabolites for d_HbA1C_class: 65
# number of significant clinical tests for d_HbA1C_class: 22
# number of data points for d_GLUCOSE_class: 250
# unable to find matching sample 26.0 0.0
# unable to find matching sample 74.0 1.0
# unable to find matching sample 78.0 0.0
# unable to find matching sample 26.0 0.0
# unable to find matching sample 29.0 0.0
# unable to find matching sample 26.0 0.0
# unable to find matching sample 24.0 0.0
# number of significant proteins for d_GLUCOSE_class: 0
# number of significant metabolites for d_GLUCOSE_class: 0
# number of significant clinical tests for d_GLUCOSE_class: 2
# number of data points for d_INSULIN_class: 453
# unable to find matching sample 26.0 0.0
# unable to find matching sample 30.0 0.0
# unable to find matching sample 29.0 0.0
# unable to find matching sample 33.0 0.0
# unable to find matching sample 26.0 0.0
# unable to find matching sample 36.0 0.0
# unable to find matching sample 24.0 0.0
# unable to find matching sample 34.0 0.0
# unable to find matching sample 37.0 0.0
# unable to find matching sample 38.0 0.0
# unable to find matching sample 37.0 1.0
# unable to find matching sample 44.0 0.0
# unable to find matching sample 24.0 1.0
# unable to find matching sample 39.0 0.0
# unable to find matching sample 45.0 0.0
# unable to find matching sample 42.0 0.0
# no matching sample found
# unable to find matching sample 33.0 1.0
# unable to find matching sample 25.0 1.0
# unable to find matching sample 48.0 0.0
# unable to find matching sample 37.0 1.0
# unable to find matching sample 34.0 1.0
# unable to find matching sample 42.0 1.0
# unable to find matching sample 43.0 0.0
# unable to find matching sample 48.0 0.0
# unable to find matching sample 33.0 1.0
# unable to find matching sample 50.0 0.0
# unable to find matching sample 45.0 1.0
# unable to find matching sample 48.0 0.0
# unable to find matching sample 35.0 0.0
# no matching sample found
# unable to find matching sample 46.0 0.0
# no matching sample found
# unable to find matching sample 31.0 1.0
# no matching sample found
# unable to find matching sample 34.0 0.0
# no matching sample found
# unable to find matching sample 43.0 0.0
# no matching sample found
# unable to find matching sample 37.0 1.0
# unable to find matching sample 33.0 0.0
# no matching sample found
# unable to find matching sample 49.0 0.0
# no matching sample found
# unable to find matching sample 50.0 0.0
# unable to find matching sample 46.0 0.0
# no matching sample found
# unable to find matching sample 29.0 0.0
# no matching sample found
# unable to find matching sample 56.0 0.0
# unable to find matching sample 48.0 0.0
# no matching sample found
# unable to find matching sample 58.0 0.0
# unable to find matching sample 58.0 0.0
# unable to find matching sample 48.0 0.0
# no matching sample found
# unable to find matching sample 31.0 1.0
# no matching sample found
# unable to find matching sample 35.0 1.0
# no matching sample found
# unable to find matching sample 43.0 1.0
# unable to find matching sample 57.0 0.0
# unable to find matching sample 58.0 0.0
# unable to find matching sample 37.0 1.0
# no matching sample found
# unable to find matching sample 59.0 0.0
# unable to find matching sample 52.0 0.0
# no matching sample found
# unable to find matching sample 57.0 0.0
# no matching sample found
# unable to find matching sample 30.0 1.0
# no matching sample found
# unable to find matching sample 57.0 0.0
# no matching sample found
# unable to find matching sample 40.0 0.0
# no matching sample found
# unable to find matching sample 43.0 0.0
# no matching sample found
# unable to find matching sample 44.0 0.0
# no matching sample found
# unable to find matching sample 46.0 0.0
# no matching sample found
# unable to find matching sample 63.0 0.0
# unable to find matching sample 52.0 0.0
# no matching sample found
# unable to find matching sample 45.0 1.0
# no matching sample found
# unable to find matching sample 42.0 1.0
# no matching sample found
# unable to find matching sample 56.0 0.0
# no matching sample found
# unable to find matching sample 57.0 0.0
# no matching sample found
# unable to find matching sample 46.0 0.0
# no matching sample found
# unable to find matching sample 47.0 1.0
# no matching sample found
# unable to find matching sample 32.0 0.0
# no matching sample found
# unable to find matching sample 39.0 0.0
# no matching sample found
# unable to find matching sample 54.0 1.0
# unable to find matching sample 50.0 1.0
# unable to find matching sample 60.0 0.0
# unable to find matching sample 64.0 0.0
# unable to find matching sample 36.0 1.0
# no matching sample found
# unable to find matching sample 44.0 0.0
# no matching sample found
# unable to find matching sample 35.0 0.0
# no matching sample found
# unable to find matching sample 49.0 0.0
# no matching sample found
# unable to find matching sample 55.0 0.0
# no matching sample found
# unable to find matching sample 48.0 1.0
# unable to find matching sample 53.0 0.0
# no matching sample found
# unable to find matching sample 64.0 0.0
# no matching sample found
# unable to find matching sample 52.0 0.0
# no matching sample found
# unable to find matching sample 40.0 1.0
# no matching sample found
# unable to find matching sample 61.0 0.0
# no matching sample found
# unable to find matching sample 49.0 1.0
# unable to find matching sample 57.0 0.0
# no matching sample found
# unable to find matching sample 47.0 1.0
# no matching sample found
# unable to find matching sample 75.0 0.0
# unable to find matching sample 39.0 0.0
# no matching sample found
# unable to find matching sample 37.0 0.0
# no matching sample found
# unable to find matching sample 36.0 0.0
# no matching sample found
# unable to find matching sample 47.0 0.0
# no matching sample found
# unable to find matching sample 48.0 1.0
# no matching sample found
# unable to find matching sample 57.0 0.0
# no matching sample found
# unable to find matching sample 38.0 0.0
# no matching sample found
# unable to find matching sample 51.0 1.0
# unable to find matching sample 30.0 1.0
# no matching sample found
# unable to find matching sample 38.0 1.0
# no matching sample found
# unable to find matching sample 60.0 0.0
# no matching sample found
# unable to find matching sample 53.0 0.0
# no matching sample found
# unable to find matching sample 27.0 1.0
# no matching sample found
# unable to find matching sample 59.0 0.0
# no matching sample found
# unable to find matching sample 34.0 0.0
# no matching sample found
# unable to find matching sample 56.0 0.0
# no matching sample found
# unable to find matching sample 61.0 0.0
# no matching sample found
# unable to find matching sample 54.0 0.0
# no matching sample found
# unable to find matching sample 31.0 1.0
# no matching sample found
# unable to find matching sample 64.0 0.0
# no matching sample found
# unable to find matching sample 29.0 0.0
# no matching sample found
# unable to find matching sample 39.0 1.0
# no matching sample found
# unable to find matching sample 26.0 0.0
# no matching sample found
# unable to find matching sample 32.0 1.0
# no matching sample found
# unable to find matching sample 41.0 0.0
# no matching sample found
# unable to find matching sample 49.0 0.0
# no matching sample found
# unable to find matching sample 61.0 0.0
# no matching sample found
# unable to find matching sample 62.0 0.0
# no matching sample found
# unable to find matching sample 45.0 1.0
# no matching sample found
# unable to find matching sample 51.0 0.0
# no matching sample found
# unable to find matching sample 41.0 1.0
# no matching sample found
# unable to find matching sample 69.0 0.0
# no matching sample found
# unable to find matching sample 58.0 0.0
# no matching sample found
# unable to find matching sample 24.0 0.0
# no matching sample found
# unable to find matching sample 48.0 0.0
# no matching sample found
# unable to find matching sample 43.0 0.0
# no matching sample found
# unable to find matching sample 56.0 1.0
# unable to find matching sample 56.0 1.0
# unable to find matching sample 37.0 1.0
# no matching sample found
# unable to find matching sample 65.0 0.0
# no matching sample found
# unable to find matching sample 68.0 0.0
# no matching sample found
# unable to find matching sample 33.0 1.0
# no matching sample found
# unable to find matching sample 34.0 0.0
# no matching sample found
# unable to find matching sample 52.0 1.0
# no matching sample found
# unable to find matching sample 32.0 0.0
# no matching sample found
# unable to find matching sample 47.0 0.0
# no matching sample found
# unable to find matching sample 57.0 0.0
# no matching sample found
# unable to find matching sample 32.0 1.0
# no matching sample found
# unable to find matching sample 52.0 0.0
# no matching sample found
# unable to find matching sample 41.0 0.0
# no matching sample found
# unable to find matching sample 43.0 0.0
# no matching sample found
# unable to find matching sample 59.0 1.0
# unable to find matching sample 59.0 0.0
# no matching sample found
# unable to find matching sample 51.0 0.0
# no matching sample found
# unable to find matching sample 63.0 0.0
# no matching sample found
# unable to find matching sample 65.0 1.0
# unable to find matching sample 63.0 0.0
# no matching sample found
# unable to find matching sample 41.0 1.0
# no matching sample found
# unable to find matching sample 55.0 0.0
# no matching sample found
# unable to find matching sample 38.0 1.0
# no matching sample found
# unable to find matching sample 44.0 1.0
# no matching sample found
# unable to find matching sample 53.0 0.0
# no matching sample found
# unable to find matching sample 53.0 0.0
# no matching sample found
# unable to find matching sample 61.0 0.0
# no matching sample found
# unable to find matching sample 32.0 0.0
# no matching sample found
# unable to find matching sample 51.0 0.0
# no matching sample found
# unable to find matching sample 31.0 1.0
# no matching sample found
# unable to find matching sample 50.0 1.0
# no matching sample found
# unable to find matching sample 54.0 1.0
# no matching sample found
# unable to find matching sample 35.0 0.0
# no matching sample found
# unable to find matching sample 28.0 1.0
# no matching sample found
# unable to find matching sample 69.0 1.0
# number of significant proteins for d_INSULIN_class: 9
# number of significant metabolites for d_INSULIN_class: 11
# number of significant clinical tests for d_INSULIN_class: 14
# number of data points for d_HOMA-IR_class: 455
# unable to find matching sample 26.0 0.0
# unable to find matching sample 30.0 0.0
# unable to find matching sample 29.0 0.0
# unable to find matching sample 26.0 0.0
# unable to find matching sample 36.0 0.0
# unable to find matching sample 37.0 0.0
# unable to find matching sample 35.0 0.0
# unable to find matching sample 24.0 0.0
# no matching sample found
# unable to find matching sample 34.0 0.0
# unable to find matching sample 37.0 0.0
# unable to find matching sample 38.0 0.0
# unable to find matching sample 32.0 1.0
# unable to find matching sample 24.0 1.0
# unable to find matching sample 45.0 0.0
# unable to find matching sample 39.0 0.0
# unable to find matching sample 45.0 0.0
# unable to find matching sample 42.0 0.0
# unable to find matching sample 33.0 1.0
# unable to find matching sample 25.0 1.0
# unable to find matching sample 48.0 0.0
# unable to find matching sample 34.0 1.0
# unable to find matching sample 42.0 1.0
# unable to find matching sample 43.0 0.0
# unable to find matching sample 48.0 0.0
# unable to find matching sample 33.0 1.0
# no matching sample found
# unable to find matching sample 50.0 0.0
# unable to find matching sample 48.0 0.0
# unable to find matching sample 35.0 0.0
# no matching sample found
# unable to find matching sample 31.0 1.0
# no matching sample found
# unable to find matching sample 34.0 0.0
# no matching sample found
# unable to find matching sample 43.0 0.0
# no matching sample found
# unable to find matching sample 37.0 1.0
# unable to find matching sample 33.0 0.0
# no matching sample found
# unable to find matching sample 49.0 0.0
# no matching sample found
# unable to find matching sample 50.0 0.0
# unable to find matching sample 46.0 0.0
# no matching sample found
# unable to find matching sample 29.0 0.0
# no matching sample found
# unable to find matching sample 56.0 0.0
# unable to find matching sample 48.0 0.0
# no matching sample found
# unable to find matching sample 58.0 0.0
# unable to find matching sample 58.0 0.0
# unable to find matching sample 48.0 0.0
# no matching sample found
# unable to find matching sample 31.0 1.0
# no matching sample found
# unable to find matching sample 35.0 1.0
# no matching sample found
# unable to find matching sample 43.0 1.0
# unable to find matching sample 57.0 0.0
# unable to find matching sample 58.0 0.0
# unable to find matching sample 37.0 1.0
# no matching sample found
# unable to find matching sample 52.0 0.0
# no matching sample found
# unable to find matching sample 57.0 0.0
# unable to find matching sample 30.0 1.0
# no matching sample found
# unable to find matching sample 57.0 0.0
# unable to find matching sample 40.0 0.0
# no matching sample found
# unable to find matching sample 43.0 0.0
# no matching sample found
# unable to find matching sample 44.0 0.0
# no matching sample found
# unable to find matching sample 46.0 0.0
# no matching sample found
# unable to find matching sample 52.0 0.0
# no matching sample found
# unable to find matching sample 45.0 1.0
# no matching sample found
# unable to find matching sample 42.0 1.0
# no matching sample found
# unable to find matching sample 56.0 0.0
# no matching sample found
# unable to find matching sample 43.0 1.0
# no matching sample found
# unable to find matching sample 57.0 0.0
# no matching sample found
# unable to find matching sample 46.0 0.0
# no matching sample found
# unable to find matching sample 46.0 0.0
# no matching sample found
# unable to find matching sample 47.0 1.0
# no matching sample found
# unable to find matching sample 32.0 0.0
# no matching sample found
# unable to find matching sample 39.0 0.0
# no matching sample found
# unable to find matching sample 54.0 1.0
# unable to find matching sample 50.0 1.0
# unable to find matching sample 60.0 0.0
# unable to find matching sample 64.0 0.0
# unable to find matching sample 36.0 1.0
# no matching sample found
# unable to find matching sample 44.0 0.0
# no matching sample found
# unable to find matching sample 49.0 0.0
# no matching sample found
# unable to find matching sample 55.0 0.0
# no matching sample found
# unable to find matching sample 48.0 1.0
# no matching sample found
# unable to find matching sample 53.0 0.0
# no matching sample found
# unable to find matching sample 64.0 0.0
# no matching sample found
# unable to find matching sample 52.0 0.0
# no matching sample found
# unable to find matching sample 40.0 1.0
# no matching sample found
# unable to find matching sample 61.0 0.0
# no matching sample found
# unable to find matching sample 49.0 1.0
# no matching sample found
# unable to find matching sample 57.0 0.0
# no matching sample found
# unable to find matching sample 47.0 1.0
# no matching sample found
# unable to find matching sample 75.0 0.0
# unable to find matching sample 39.0 0.0
# no matching sample found
# unable to find matching sample 37.0 0.0
# no matching sample found
# unable to find matching sample 36.0 0.0
# no matching sample found
# unable to find matching sample 47.0 0.0
# no matching sample found
# unable to find matching sample 48.0 1.0
# no matching sample found
# unable to find matching sample 57.0 0.0
# no matching sample found
# unable to find matching sample 38.0 0.0
# no matching sample found
# unable to find matching sample 51.0 1.0
# unable to find matching sample 30.0 1.0
# no matching sample found
# unable to find matching sample 38.0 1.0
# no matching sample found
# unable to find matching sample 60.0 0.0
# no matching sample found
# unable to find matching sample 53.0 0.0
# no matching sample found
# unable to find matching sample 27.0 1.0
# no matching sample found
# unable to find matching sample 69.0 1.0
# unable to find matching sample 49.0 1.0
# no matching sample found
# unable to find matching sample 26.0 0.0
# no matching sample found
# unable to find matching sample 59.0 0.0
# no matching sample found
# unable to find matching sample 34.0 0.0
# no matching sample found
# unable to find matching sample 56.0 0.0
# no matching sample found
# unable to find matching sample 61.0 0.0
# no matching sample found
# unable to find matching sample 54.0 0.0
# no matching sample found
# unable to find matching sample 64.0 0.0
# no matching sample found
# unable to find matching sample 29.0 0.0
# no matching sample found
# unable to find matching sample 39.0 1.0
# no matching sample found
# unable to find matching sample 26.0 0.0
# no matching sample found
# unable to find matching sample 32.0 1.0
# no matching sample found
# unable to find matching sample 41.0 0.0
# no matching sample found
# unable to find matching sample 49.0 0.0
# no matching sample found
# unable to find matching sample 61.0 0.0
# no matching sample found
# unable to find matching sample 62.0 0.0
# no matching sample found
# unable to find matching sample 29.0 1.0
# no matching sample found
# unable to find matching sample 45.0 1.0
# no matching sample found
# unable to find matching sample 41.0 1.0
# no matching sample found
# unable to find matching sample 69.0 0.0
# no matching sample found
# unable to find matching sample 58.0 0.0
# no matching sample found
# unable to find matching sample 24.0 0.0
# no matching sample found
# unable to find matching sample 48.0 0.0
# no matching sample found
# unable to find matching sample 43.0 0.0
# no matching sample found
# unable to find matching sample 56.0 1.0
# unable to find matching sample 56.0 1.0
# unable to find matching sample 37.0 1.0
# no matching sample found
# unable to find matching sample 65.0 0.0
# no matching sample found
# unable to find matching sample 68.0 0.0
# no matching sample found
# unable to find matching sample 33.0 1.0
# no matching sample found
# unable to find matching sample 34.0 0.0
# no matching sample found
# unable to find matching sample 52.0 1.0
# no matching sample found
# unable to find matching sample 32.0 0.0
# no matching sample found
# unable to find matching sample 47.0 0.0
# no matching sample found
# unable to find matching sample 57.0 0.0
# no matching sample found
# unable to find matching sample 32.0 1.0
# no matching sample found
# unable to find matching sample 52.0 0.0
# no matching sample found
# unable to find matching sample 41.0 0.0
# no matching sample found
# unable to find matching sample 43.0 0.0
# no matching sample found
# unable to find matching sample 59.0 1.0
# no matching sample found
# unable to find matching sample 59.0 0.0
# no matching sample found
# unable to find matching sample 51.0 0.0
# no matching sample found
# unable to find matching sample 63.0 0.0
# no matching sample found
# unable to find matching sample 65.0 1.0
# unable to find matching sample 63.0 0.0
# no matching sample found
# unable to find matching sample 41.0 1.0
# no matching sample found
# unable to find matching sample 55.0 0.0
# no matching sample found
# unable to find matching sample 38.0 1.0
# no matching sample found
# unable to find matching sample 44.0 1.0
# no matching sample found
# unable to find matching sample 53.0 0.0
# no matching sample found
# unable to find matching sample 53.0 0.0
# no matching sample found
# unable to find matching sample 61.0 0.0
# no matching sample found
# unable to find matching sample 32.0 0.0
# no matching sample found
# unable to find matching sample 51.0 0.0
# no matching sample found
# unable to find matching sample 31.0 1.0
# no matching sample found
# unable to find matching sample 50.0 1.0
# no matching sample found
# unable to find matching sample 54.0 1.0
# no matching sample found
# unable to find matching sample 35.0 0.0
# no matching sample found
# unable to find matching sample 28.0 1.0
# no matching sample found
# unable to find matching sample 69.0 1.0
# no matching sample found
# number of significant proteins for d_HOMA-IR_class: 0
# number of significant metabolites for d_HOMA-IR_class: 8
# number of significant clinical tests for d_HOMA-IR_class: 14
# number of data points for d_GFR_class: 299
# unable to find matching sample 80.0 1.0
# unable to find matching sample 87.0 0.0
# unable to find matching sample 78.0 0.0
# unable to find matching sample 75.0 0.0
# unable to find matching sample 26.0 1.0
# unable to find matching sample 26.0 1.0
# unable to find matching sample 78.0 1.0
# number of significant proteins for d_GFR_class: 0
# number of significant metabolites for d_GFR_class: 0
# number of significant clinical tests for d_GFR_class: 1
# number of data points for GLYCOHEMOGLOBIN A1C: 32
# number of significant proteins for GLYCOHEMOGLOBIN A1C: 30
# number of significant metabolites for GLYCOHEMOGLOBIN A1C: 56
# number of significant clinical tests for GLYCOHEMOGLOBIN A1C: 19
# number of data points for GLUCOSE: 26
# number of significant proteins for GLUCOSE: 0
# number of significant metabolites for GLUCOSE: 6
# number of significant clinical tests for GLUCOSE: 7

# %% [markdown]
# ### Exporting protein and metabolite tables

# %%
prot_names = pd.read_csv('../arivale_data/arivale_prots.tsv', sep='\t')
met_names = pd.read_csv('../arivale_data/arivale_mets.tsv', sep='\t')

# %%
met_names.index = met_names.CHEMICAL_ID
prot_names.index = prot_names['index']

# %%
top_prots = prot_names.copy()
top_mets = met_names.copy()

# %%
prot_new_cols = []
met_new_cols = []
for var, diffexp_output in zip(variables, diffexp_outputs):
    column1_name = 'positive_' + var + '_mean_diff'
    column2_name = 'positive_' + var + '_pvals'
    top_prots[column1_name] = diffexp_output[0]
    top_prots[column2_name] = diffexp_output[1]
    prot_new_cols += [column1_name, column2_name]
    diffexp_output[2].index = diffexp_output[2].index.astype(int)
    diffexp_output[3].index = diffexp_output[3].index.astype(int)
    top_mets[column1_name] = diffexp_output[2]
    top_mets[column2_name] = diffexp_output[3]
    met_new_cols += [column1_name, column2_name]
    
# TODO: add current variables too
for var, diffexp_output in zip(base_variables, base_diffexp_outputs):
    column1_name = 'high_' + var + '_mean_diff'
    column2_name = 'high_' + var + '_pvals'
    top_prots[column1_name] = diffexp_output[0]
    top_prots[column2_name] = diffexp_output[1]
    prot_new_cols += [column1_name, column2_name]
    diffexp_output[2].index = diffexp_output[2].index.astype(int)
    diffexp_output[3].index = diffexp_output[3].index.astype(int)
    top_mets[column1_name] = diffexp_output[2]
    top_mets[column2_name] = diffexp_output[3]
    met_new_cols += [column1_name, column2_name]

# %%
top_prots = top_prots[['name', 'uniprot', 'gene_name'] + prot_new_cols]

# %%
top_prots = top_prots[~top_prots.positive_d_HbA1C_class_mean_diff.isna()]

# %%
top_prots.to_csv('results_2023_10_18/prots_diffexp_d_hba1c.csv', index=None)

# %%
top_mets = top_mets[['index', 'CHEMBL', 'KEGG', 'PUBCHEM'] + met_new_cols]

# %%
top_mets = top_mets[~top_mets['positive_d_HbA1C_class_mean_diff'].isna()]

# %%
top_mets.to_csv('results_2023_10_18/mets_diffexp_d_hba1c.csv', index=None)

# %% [markdown]
# ### Export clinical table

# %%
clinical_columns = {}
for var, diffexp_output in zip(variables, diffexp_outputs):
    column1_name = 'positive_' + var + '_mean_diff'
    column2_name = 'positive_' + var + '_pvals'
    clinical_columns[column1_name] = diffexp_output[4]
    clinical_columns[column2_name] = diffexp_output[5]
    
for var, diffexp_output in zip(base_variables, base_diffexp_outputs):
    column1_name = 'high_' + var + '_mean_diff'
    column2_name = 'high_' + var + '_pvals'
    clinical_columns[column1_name] = diffexp_output[4]
    clinical_columns[column2_name] = diffexp_output[5]

# %%
clinical_diffexp = pd.DataFrame(clinical_columns)

# %%
clinical_diffexp.sort_values('positive_d_HbA1C_class_pvals')
# Out:
#                       positive_d_HbA1C_class_mean_diff  \
# MCHC                                         -0.978108
# TNF-ALPHA                                     0.430514
# GLYCOHEMOGLOBIN A1C                          -0.290811
# BASOPHILS ABSOLUTE                            0.006541
# ZINC                                       -175.602703
# ...                                                ...
# CHOLESTEROL, TOTAL                            1.732432
# CARBON DIOXIDE (CO2)                          0.267568
# BUN/CREAT RATIO                               0.118919
# DHA                                           0.044865
# CALCIUM                                       0.012973
#
#                       positive_d_HbA1C_class_pvals  \
# MCHC                                  1.595983e-26
# TNF-ALPHA                             2.601741e-24
# GLYCOHEMOGLOBIN A1C                   6.024600e-16
# BASOPHILS ABSOLUTE                    9.079976e-16
# ZINC                                  2.530183e-15
# ...                                            ...
# CHOLESTEROL, TOTAL                    1.000000e+00
# CARBON DIOXIDE (CO2)                  1.000000e+00
# BUN/CREAT RATIO                       1.000000e+00
# DHA                                   1.000000e+00
# CALCIUM                               1.000000e+00
#
#                       positive_d_GLUCOSE_class_mean_diff  \
# MCHC                                             0.14820
# TNF-ALPHA                                       -0.43852
# GLYCOHEMOGLOBIN A1C                              0.04700
# BASOPHILS ABSOLUTE                              -0.00208
# ZINC                                            61.81600
# ...                                                  ...
# CHOLESTEROL, TOTAL                               0.86600
# CARBON DIOXIDE (CO2)                             0.15400
# BUN/CREAT RATIO                                 -0.53000
# DHA                                             -0.01540
# CALCIUM                                         -0.01540
#
#                       positive_d_GLUCOSE_class_pvals  \
# MCHC                                        1.000000
# TNF-ALPHA                                   1.000000
# GLYCOHEMOGLOBIN A1C                         1.000000
# BASOPHILS ABSOLUTE                          0.685669
# ZINC                                        0.084763
# ...                                              ...
# CHOLESTEROL, TOTAL                          1.000000
# CARBON DIOXIDE (CO2)                        1.000000
# BUN/CREAT RATIO                             1.000000
# DHA                                         1.000000
# CALCIUM                                     1.000000
#
#                       positive_d_INSULIN_class_mean_diff  \
# MCHC                                            0.347070
# TNF-ALPHA                                       0.041303
# GLYCOHEMOGLOBIN A1C                            -0.007241
# BASOPHILS ABSOLUTE                             -0.001796
# ZINC                                           82.138532
# ...                                                  ...
# CHOLESTEROL, TOTAL                             -3.518930
# CARBON DIOXIDE (CO2)                           -0.114145
# BUN/CREAT RATIO                                -0.435110
# DHA                                             0.050085
# CALCIUM                                        -0.035250
#
#                       positive_d_INSULIN_class_pvals  \
# MCHC                                    3.467682e-06
# TNF-ALPHA                               7.898377e-11
# GLYCOHEMOGLOBIN A1C                     1.000000e+00
# BASOPHILS ABSOLUTE                      2.786807e-05
# ZINC                                    3.853726e-07
# ...                                              ...
# CHOLESTEROL, TOTAL                      1.000000e+00
# CARBON DIOXIDE (CO2)                    1.000000e+00
# BUN/CREAT RATIO                         3.439630e-01
# DHA                                     1.000000e+00
# CALCIUM                                 1.000000e+00
#
#                       positive_d_HOMA-IR_class_mean_diff  \
# MCHC                                            0.337403
# TNF-ALPHA                                       0.059137
# GLYCOHEMOGLOBIN A1C                            -0.012788
# BASOPHILS ABSOLUTE                             -0.002438
# ZINC                                           83.261359
# ...                                                  ...
# CHOLESTEROL, TOTAL                             -3.840081
# CARBON DIOXIDE (CO2)                           -0.063785
# BUN/CREAT RATIO                                -0.346829
# DHA                                             0.037747
# CALCIUM                                        -0.019282
#
#                       positive_d_HOMA-IR_class_pvals  \
# MCHC                                    7.528307e-06
# TNF-ALPHA                               1.015069e-08
# GLYCOHEMOGLOBIN A1C                     1.000000e+00
# BASOPHILS ABSOLUTE                      3.322422e-05
# ZINC                                    1.610602e-07
# ...                                              ...
# CHOLESTEROL, TOTAL                      1.000000e+00
# CARBON DIOXIDE (CO2)                    1.000000e+00
# BUN/CREAT RATIO                         6.908400e-01
# DHA                                     1.000000e+00
# CALCIUM                                 1.000000e+00
#
#                       positive_d_GFR_class_mean_diff  \
# MCHC                                        0.267092
# TNF-ALPHA                                   0.369163
# GLYCOHEMOGLOBIN A1C                         0.071093
# BASOPHILS ABSOLUTE                         -0.001266
# ZINC                                       13.344308
# ...                                              ...
# CHOLESTEROL, TOTAL                         -4.435236
# CARBON DIOXIDE (CO2)                       -0.075724
# BUN/CREAT RATIO                             0.451460
# DHA                                        -0.146511
# CALCIUM                                    -0.026415
#
#                       positive_d_GFR_class_pvals  \
# MCHC                                    0.060265
# TNF-ALPHA                               0.077810
# GLYCOHEMOGLOBIN A1C                     0.489075
# BASOPHILS ABSOLUTE                      0.812049
# ZINC                                    1.000000
# ...                                          ...
# CHOLESTEROL, TOTAL                      1.000000
# CARBON DIOXIDE (CO2)                    1.000000
# BUN/CREAT RATIO                         1.000000
# DHA                                     0.446854
# CALCIUM                                 1.000000
#
#                       high_GLYCOHEMOGLOBIN A1C_mean_diff  \
# MCHC                                            0.034375
# TNF-ALPHA                                      -2.824063
# GLYCOHEMOGLOBIN A1C                             1.696875
# BASOPHILS ABSOLUTE                             -0.002656
# ZINC                                           75.328125
# ...                                                  ...
# CHOLESTEROL, TOTAL                            -17.906250
# CARBON DIOXIDE (CO2)                           -0.609375
# BUN/CREAT RATIO                                 0.328125
# DHA                                            -0.026563
# CALCIUM                                         0.032813
#
#                       high_GLYCOHEMOGLOBIN A1C_pvals  high_GLUCOSE_mean_diff  \
# MCHC                                    1.000000e+00                0.475000
# TNF-ALPHA                               1.000000e+00               -0.479423
# GLYCOHEMOGLOBIN A1C                     5.147161e-13                1.515385
# BASOPHILS ABSOLUTE                      1.000000e+00               -0.012308
# ZINC                                    1.000000e+00              134.480769
# ...                                              ...                     ...
# CHOLESTEROL, TOTAL                      2.213862e-01               -9.942308
# CARBON DIOXIDE (CO2)                    1.000000e+00               -1.019231
# BUN/CREAT RATIO                         1.000000e+00                0.615385
# DHA                                     1.000000e+00               -0.078846
# CALCIUM                                 1.000000e+00                0.094231
#
#                       high_GLUCOSE_pvals
# MCHC                        8.812552e-01
# TNF-ALPHA                   4.889036e-01
# GLYCOHEMOGLOBIN A1C         4.614941e-08
# BASOPHILS ABSOLUTE          1.998145e-01
# ZINC                        8.156304e-01
# ...                                  ...
# CHOLESTEROL, TOTAL          1.000000e+00
# CARBON DIOXIDE (CO2)        3.767755e-01
# BUN/CREAT RATIO             1.000000e+00
# DHA                         1.000000e+00
# CALCIUM                     1.000000e+00
#
# [70 rows x 14 columns]

# %%
clinical_diffexp.to_csv('results_2023_10_18/clinical_diffexp_d_hba1c.csv')
